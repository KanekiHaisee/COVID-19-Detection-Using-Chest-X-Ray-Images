# %% [markdown]
# # 1) IMPORTING LIBRARIES

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D,Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 2) CLONING DATASET

# %%
# CLONING THE DATASET FROM THE GITHUB REPOSITORY
# !git clone https://github.com/RishitToteja/Chext-X-ray-Images-Data-Set.git
# Out:
# Cloning into 'Chext-X-ray-Images-Data-Set'...
# remote: Enumerating objects: 2319, done.
# remote: Total 2319 (delta 0), reused 0 (delta 0), pack-reused 2319
# Receiving objects: 100% (2319/2319), 1.31 GiB | 16.39 MiB/s, done.

# %%
import os

main_dir = "/content/Chext-X-ray-Images-Data-Set/DataSet/Data"

# SETTING TRAIN AND TEST DIRECTORY
train_dir = os.path.join(main_dir, "train")
test_dir = os.path.join(main_dir, "test")

#SETING DIRECTORY FOR COVID AND NORMAL IMAGES DIRECTORY
train_covid_dir = os.path.join(train_dir, "COVID19")
train_normal_dir = os.path.join(train_dir, "NORMAL")

test_covid_dir = os.path.join(test_dir, "COVID19")
test_normal_dir = os.path.join(test_dir, "NORMAL")

# %%
# MAKING SEPERATE FILES :
train_covid_names = os.listdir(train_covid_dir)
train_normal_names = os.listdir(train_normal_dir)

test_covid_names = os.listdir(test_covid_dir)
test_normal_names = os.listdir(test_normal_dir)

# %% [markdown]
# # 3) PERFORMING DATA VISUALIZATION

# %%
import matplotlib.image as mpimg

rows = 4
columns = 4

fig = plt.gcf()
fig.set_size_inches(12,12)

covid_img = [os.path.join(train_covid_dir, filename) for filename in train_covid_names[0:8]]
normal_img = [os.path.join(train_normal_dir, filename) for filename in train_normal_names[0:8]]

print(covid_img)
print(normal_img)

merged_img = covid_img + normal_img

for i, img_path in enumerate(merged_img):
  title = img_path.split("/", 6)[6]
  plot = plt.subplot(rows, columns, i+1)
  plot.axis("Off")
  img = mpimg.imread(img_path)
  plot.set_title(title, fontsize = 11)
  plt.imshow(img, cmap= "gray")

plt.show()
# Out:
# ['/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(435).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(559).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(342).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID-19 (11).jpeg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID-19 (2).jpeg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(417).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(560).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID-19 (299).jpg']
# ['/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(524).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1110).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(176).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1068).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1421).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(507).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1177).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(730).jpg']

# %% [markdown]
# # 4) DATA PREPROCESSING AND AUGMENTATION

# %%
# CREATING TRAINING, TESTING AND VALIDATION BATCHES

dgen_train = ImageDataGenerator(rescale = 1./255,
                                validation_split = 0.2,
                                zoom_range = 0.2,
                                horizontal_flip = True)

dgen_validation = ImageDataGenerator(rescale = 1./255,
                                     )

dgen_test = ImageDataGenerator(rescale = 1./255,
                              )

train_generator = dgen_train.flow_from_directory(train_dir,
                                                 target_size = (150, 150),
                                                 subset = 'training',
                                                 batch_size = 32,
                                                 class_mode = 'binary')
validation_generator = dgen_train.flow_from_directory(train_dir,
                                                      target_size = (150, 150),
                                                      subset = "validation",
                                                      batch_size = 32,
                                                      class_mode = "binary")
test_generator = dgen_test.flow_from_directory(test_dir,
                                               target_size = (150, 150),
                                               batch_size = 32,
                                               class_mode = "binary")
# Out:
# Found 1449 images belonging to 2 classes.
# Found 362 images belonging to 2 classes.
# Found 484 images belonging to 2 classes.

# %%
print("Class Labels are: ", train_generator.class_indices)
print("Image shape is : ", train_generator.image_shape)
# Out:
# Class Labels are:  {'COVID19': 0, 'NORMAL': 1}
# Image shape is :  (150, 150, 3)

# %% [markdown]
# # 5) BUILDING CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D

model = Sequential()

# 1) CONVOLUTIONAL LAYER - 1
model.add(Conv2D(32, (5,5), padding = "same", activation = "relu", input_shape = train_generator.image_shape))

# 2) POOLING LAYER - 1
model.add(MaxPooling2D(pool_size=(2,2)))

# 3) DROPOUT LAYER -2
model.add(Dropout(0.5))

# 4) CONVOLUTIONAL LAYER - 2
model.add(Conv2D(64, (5,5), padding = "same", activation = "relu"))

# 5) POOLING LAYER - 2
model.add(MaxPooling2D(pool_size=(2,2)))

# 6) DROPOUT LAYER - 2
model.add(Dropout(0.5))

# 7) FLATTENING LAYER TO 2D SHAPE
model.add(Flatten())

# 8) ADDING A DENSE LAYER
model.add(Dense(256, activation = 'relu'))

# 9 DROPOUT LAYER - 3
model.add(Dropout(0.5))

# 10) FINAL OUTPUT LAYER
model.add(Dense(1, activation = 'sigmoid'))

### PRINTING MODEL SUMMARY
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 87616)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               22429952
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 22,483,905
# Trainable params: 22,483,905
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 6) COMPILING AND TRAINING THE NEURAL NETWORK MODEL

# %%
# COMPILING THE MODEL

model.compile(Adam(learning_rate = 0.001), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# TRAINING THE MODEL
history = model.fit(train_generator,
                    epochs = 35,
                    validation_data = validation_generator)
# Out:
# Epoch 1/35
# 46/46 [==============================] - 80s 1s/step - loss: 1.1209 - accuracy: 0.6729 - val_loss: 0.4860 - val_accuracy: 0.9006
# Epoch 2/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.2157 - accuracy: 0.9193 - val_loss: 0.1927 - val_accuracy: 0.9530
# Epoch 3/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1815 - accuracy: 0.9296 - val_loss: 0.1787 - val_accuracy: 0.9530
# Epoch 4/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.1624 - accuracy: 0.9420 - val_loss: 0.1548 - val_accuracy: 0.9558
# Epoch 5/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1528 - accuracy: 0.9455 - val_loss: 0.1657 - val_accuracy: 0.9669
# Epoch 6/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.1321 - accuracy: 0.9551 - val_loss: 0.1425 - val_accuracy: 0.9530
# Epoch 7/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.1270 - accuracy: 0.9558 - val_loss: 0.1040 - val_accuracy: 0.9613
# Epoch 8/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.1493 - accuracy: 0.9510 - val_loss: 0.2128 - val_accuracy: 0.9420
# Epoch 9/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.1336 - accuracy: 0.9517 - val_loss: 0.1904 - val_accuracy: 0.9282
# Epoch 10/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1413 - accuracy: 0.9551 - val_loss: 0.1503 - val_accuracy: 0.9724
# Epoch 11/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.1226 - accuracy: 0.9620 - val_loss: 0.1230 - val_accuracy: 0.9641
# Epoch 12/35
# 46/46 [==============================] - 48s 1s/step - loss: 0.1081 - accuracy: 0.9634 - val_loss: 0.1485 - val_accuracy: 0.9503
# Epoch 13/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1169 - accuracy: 0.9614 - val_loss: 0.0932 - val_accuracy: 0.9779
# Epoch 14/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.1093 - accuracy: 0.9627 - val_loss: 0.0948 - val_accuracy: 0.9641
# Epoch 15/35
# 46/46 [==============================] - 50s 1s/step - loss: 0.0998 - accuracy: 0.9676 - val_loss: 0.1090 - val_accuracy: 0.9669
# Epoch 16/35
# 46/46 [==============================] - 50s 1s/step - loss: 0.1292 - accuracy: 0.9614 - val_loss: 0.1167 - val_accuracy: 0.9751
# Epoch 17/35
# 46/46 [==============================] - 50s 1s/step - loss: 0.1066 - accuracy: 0.9703 - val_loss: 0.1192 - val_accuracy: 0.9613
# Epoch 18/35
# 46/46 [==============================] - 48s 1s/step - loss: 0.0986 - accuracy: 0.9710 - val_loss: 0.1657 - val_accuracy: 0.9586
# Epoch 19/35
# 46/46 [==============================] - 48s 1s/step - loss: 0.0941 - accuracy: 0.9745 - val_loss: 0.1033 - val_accuracy: 0.9558
# Epoch 20/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.0991 - accuracy: 0.9662 - val_loss: 0.1716 - val_accuracy: 0.9337
# Epoch 21/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.0782 - accuracy: 0.9717 - val_loss: 0.0659 - val_accuracy: 0.9751
# Epoch 22/35
# 46/46 [==============================] - 48s 1s/step - loss: 0.0875 - accuracy: 0.9752 - val_loss: 0.1024 - val_accuracy: 0.9641
# Epoch 23/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.0931 - accuracy: 0.9669 - val_loss: 0.0814 - val_accuracy: 0.9696
# Epoch 24/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0827 - accuracy: 0.9731 - val_loss: 0.0837 - val_accuracy: 0.9807
# Epoch 25/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0871 - accuracy: 0.9696 - val_loss: 0.1854 - val_accuracy: 0.9392
# Epoch 26/35
# 46/46 [==============================] - 48s 1s/step - loss: 0.0903 - accuracy: 0.9655 - val_loss: 0.1151 - val_accuracy: 0.9586
# Epoch 27/35
# 46/46 [==============================] - 50s 1s/step - loss: 0.0830 - accuracy: 0.9772 - val_loss: 0.0758 - val_accuracy: 0.9724
# Epoch 28/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.0852 - accuracy: 0.9717 - val_loss: 0.1665 - val_accuracy: 0.9282
# Epoch 29/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.0809 - accuracy: 0.9738 - val_loss: 0.0664 - val_accuracy: 0.9779
# Epoch 30/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.0742 - accuracy: 0.9745 - val_loss: 0.1093 - val_accuracy: 0.9613
# Epoch 31/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.0754 - accuracy: 0.9772 - val_loss: 0.0716 - val_accuracy: 0.9669
# Epoch 32/35
# 46/46 [==============================] - 48s 1s/step - loss: 0.0882 - accuracy: 0.9696 - val_loss: 0.0932 - val_accuracy: 0.9779
# Epoch 33/35
# 46/46 [==============================] - 48s 1s/step - loss: 0.0892 - accuracy: 0.9669 - val_loss: 0.1032 - val_accuracy: 0.9669
# Epoch 34/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0962 - accuracy: 0.9627 - val_loss: 0.0905 - val_accuracy: 0.9669
# Epoch 35/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.0875 - accuracy: 0.9738 - val_loss: 0.0744 - val_accuracy: 0.9779

# %% [markdown]
# # 7) PERFORMING EVALUATION

# %%
# KEYS OF HISTORY OBJECT
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# PLOT GRAPH BETWEEN TRAINING AND VALIDATION LOSS
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training', 'Validation'])
plt.title("Training and validation losses")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# PLOT GRAPH BETWEEN TRAINING AND VALIDATION ACCURACY
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training', 'Validation'])
plt.title("Training and validation accuracy")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# GETTING TEST ACCURACY AND LOSS

test_loss, test_acc = model.evaluate(test_generator)
print("Test Set Loss : ", test_loss)
print("Test Set Accuracy : ", test_acc)
# Out:
# 16/16 [==============================] - 11s 682ms/step - loss: 0.0664 - accuracy: 0.9814
# Test Set Loss :  0.06641199439764023
# Test Set Accuracy :  0.9814049601554871

# %% [markdown]
# # 9) PREDICTION ON NEW DATA (UPLOAD FILES)

# %%
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

for filename in uploaded.keys():
  img_path = '/content/' + filename
  img = image.load_img(img_path, target_size = (150,150))
  images = image.img_to_array(img)
  images = np.expand_dims(images, axis = 0)
  prediction = model.predict(images)

  if prediction == 0:
    print("The report is COVID-19 Positive")
  else:
    print("The report is COVID-19 Negative")
# Out:
#      <input type="file" id="files-e0eee881-537c-4d31-9fa4-37bdc796787b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e0eee881-537c-4d31-9fa4-37bdc796787b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WIN_20201211_12_05_28_Pro.jpg to WIN_20201211_12_05_28_Pro.jpg
# The report is COVID-19 Positive

# %%
model.save("model.h5")
